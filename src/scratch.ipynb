# %%
import pandas as pd

# %%
cointegrated_pairs = pd.read_csv("../data/manipulated/cointegrated_pairs.csv")
print(cointegrated_pairs.columns)

pr_filtered_train_residuals = pd.read_csv("../data/manipulated/pr_filtered_train_residuals.csv")
print(pr_filtered_train_residuals.columns)
# Out:
# Index(['asset_a', 'asset_b', 'pvalue', 'beta'], dtype='str')
# Index(['Date', 'CDW', 'CTSH', 'AMCR', 'HAS', 'NKE', 'APH', 'LIN', 'STZ', 'WY',
#        'EL', 'GRMN', 'APO', 'HPQ', 'BLK', 'ECL', 'CRH', 'PAYX', 'ARES', 'KKR',
#        'CBRE', 'CSX', 'ACN', 'MSI', 'IT', 'TEL'],
#       dtype='str')
