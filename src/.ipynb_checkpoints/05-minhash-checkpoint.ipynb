# %% [markdown]
# # Minhash

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasketch import MinHash, MinHashLSH

# %%
train_residuals = pd.read_csv("../data/manipulated/residuals_train.csv", index_col=0, parse_dates=True)

train_start = train_residuals.index.min()
train_end = train_residuals.index.max()

# %%
def discretise(spread_window, z_threshold=1.0):
    mean = spread_window.mean()
    std  = spread_window.std()
    z    = (spread_window - mean) / std
    
    symbols = []
    for val in z:
        if val < -1.5:       symbols.append('--')
        elif val < -0.3:     symbols.append('-')
        elif val <  0.3:     symbols.append('0')
        elif val <  1.5:     symbols.append('+')
        else:                symbols.append('++')
    return symbols

# %%
def shingle(symbols, k=3):
    return set(''.join(symbols[i:i+k]) for i in range(len(symbols) - k + 1))

# %%
df = pd.read_csv('../data/manipulated/spreads/ACN_IT.csv', index_col=0, parse_dates=True)

window = df['spread'].iloc[:20]
symbols = discretise(window)
shingles = shingle(symbols)

print(symbols)
print(shingles)
# Out:
# ['-', '+', '-', '+', '+', '0', '0', '-', '-', '++', '0', '+', '-', '-', '+', '+', '+', '--', '-', '0']
# {'+--', '--+', '+00', '+-+', '++0+', '0--', '+++', '-++', '0+-', '++--', '---0', '-+-', '--++', '+---', '++0', '00-', '-++0'}

# %%
def make_minhash(shingles, num_perm=128):
    m = MinHash(num_perm=num_perm)
    for s in shingles:
        m.update(s.encode('utf-8'))
    return m

# %%
m = make_minhash(shingles)
print(m.hashvalues[:5])
# Out:
# [ 81502543  62521195   8923789 624503728  53189819]

# %%
WINDOW_SIZE = 20

def build_lsh_index(spread, window_size=WINDOW_SIZE, num_perm=128):
    lsh = MinHashLSH(threshold=0.5, num_perm=num_perm)
    signatures = {}
    
    for i in range(len(spread) - window_size):
        window = spread.iloc[i:i + window_size]
        symbols = discretise(window)
        shingles = shingle(symbols)
        m = make_minhash(shingles)
        key = f"w_{i}"
        lsh.insert(key, m)
        signatures[key] = (m, i)  # store signature and start index for forward return lookup
    
    return lsh, signatures

# %%
spread = df['spread']
lsh, signatures = build_lsh_index(spread)
print(f"indexed {len(signatures)} windows")
# Out:
# indexed 2367 windows

# %%
def minhash_signal(spread, lsh, signatures, window_size=WINDOW_SIZE, forward_days=10, num_perm=128):
    # current window = last window_size days
    current_window = spread.iloc[-window_size:]
    symbols = discretise(current_window)
    shingles = shingle(symbols)
    query_m = make_minhash(shingles)
    
    similar_keys = lsh.query(query_m)
    
    if not similar_keys:
        return 0  # no similar windows found, no confirmation
    
    # compute forward return for each similar historical window
    forward_returns = []
    for key in similar_keys:
        _, start_idx = signatures[key]
        end_idx = start_idx + window_size + forward_days
        if end_idx < len(spread):
            forward_return = spread.iloc[start_idx + window_size + forward_days] - spread.iloc[start_idx + window_size]
            forward_returns.append(forward_return)
    
    if not forward_returns:
        return 0
    
    avg_forward_return = np.mean(forward_returns)
    return avg_forward_return

# %%
signal = minhash_signal(spread, lsh, signatures)
print(f"MinHash signal: {signal:.4f}")
# Out:
# MinHash signal: -0.0731

# %%
def combine_signals(gmm_signal, minhash_signal):
    if gmm_signal == 0:
        return 0
    # confirm if minhash agrees in direction, suppress if it disagrees
    if gmm_signal == 1 and minhash_signal > 0:
        return 1
    if gmm_signal == -1 and minhash_signal < 0:
        return -1
    return 0  # disagreement, so stay flat

# %%
print(combine_signals(1,  0.05))   # should be  1 — confirmed long
print(combine_signals(1,  -0.05))  # should be  0 — suppressed
print(combine_signals(-1, -0.05))  # should be -1 — confirmed short
print(combine_signals(0,  -0.05))  # should be  0 — no GMM signal
# Out:
# 1
# 0
# -1
# 0

# %%
def compute_minhash_signals(spread, gmm_signals, lsh, signatures, window_size=WINDOW_SIZE, forward_days=10):
    minhash_signals = pd.Series(0.0, index=spread.index)
    
    # only query on days where GMM signal is non-zero
    signal_days = gmm_signals[gmm_signals != 0].index
    
    for date in signal_days:
        i = spread.index.get_loc(date)
        if i < window_size:
            continue
        
        window = spread.iloc[i - window_size:i]
        symbols = discretise(window)
        shingles = shingle(symbols)
        query_m = make_minhash(shingles)
        
        similar_keys = lsh.query(query_m)
        if not similar_keys:
            continue
        
        forward_returns = []
        for key in similar_keys:
            _, start_idx = signatures[key]
            end_idx = start_idx + window_size + forward_days
            if end_idx < len(spread) and start_idx + window_size <= i:
                fwd = spread.iloc[start_idx + window_size + forward_days] - spread.iloc[start_idx + window_size]
                forward_returns.append(fwd)
        
        if forward_returns:
            minhash_signals.loc[date] = np.mean(forward_returns)
    
    return minhash_signals

# %%
cointegration_pairs = pd.read_csv('../data/manipulated/cointegrated_pairs.csv')

# %%
MIN_SIGNALS = 200  # minimum number of non-zero GMM signals to keep a pair

active_pairs = []

for _, row in cointegration_pairs.iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0, parse_dates=True, date_format='%Y-%m-%d')
    
    n_signals = (df['signal'] != 0).sum()
    if n_signals >= MIN_SIGNALS:
        active_pairs.append(row)
        print(f"{a}/{b} — {n_signals} signals, keeping")
    else:
        print(f"{a}/{b} — {n_signals} signals, dropping")

active_pairs = pd.DataFrame(active_pairs)
active_pairs.to_csv("../data/manipulated/active_pairs.csv")
print(f"\n{len(active_pairs)} pairs kept from {len(cointegration_pairs)}")
# Out:
# CDW/HAS — 229 signals, keeping
# CTSH/ACN — 167 signals, dropping
# CTSH/CSX — 225 signals, keeping
# CTSH/IT — 15 signals, dropping
# CTSH/MSI — 113 signals, dropping
# CDW/LIN — 155 signals, dropping
# HAS/EL — 225 signals, keeping
# HPQ/CRH — 135 signals, dropping
# AMCR/ACN — 206 signals, keeping
# AMCR/MSI — 241 signals, keeping
# AMCR/ARES — 300 signals, keeping
# AMCR/BLK — 0 signals, dropping
# AMCR/APO — 0 signals, dropping
# AMCR/EL — 224 signals, keeping
# AMCR/STZ — 110 signals, dropping
# AMCR/APH — 157 signals, dropping
# AMCR/IT — 232 signals, keeping
# HAS/STZ — 116 signals, dropping
# HAS/CRH — 398 signals, keeping
# HAS/KKR — 187 signals, dropping
# HAS/IT — 193 signals, dropping
# HAS/CBRE — 158 signals, dropping
# NKE/EL — 527 signals, keeping
# HAS/TEL — 59 signals, dropping
# ECL/MSI — 190 signals, dropping
# CRH/KKR — 0 signals, dropping
# CRH/ARES — 4 signals, dropping
# ECL/ACN — 203 signals, keeping
# HPQ/TEL — 185 signals, dropping
# HPQ/IT — 71 signals, dropping
# HPQ/ACN — 193 signals, dropping
# HPQ/KKR — 6 signals, dropping
# NKE/HPQ — 157 signals, dropping
# NKE/APO — 0 signals, dropping
# HAS/ECL — 188 signals, dropping
# HAS/HPQ — 138 signals, dropping
# APH/IT — 0 signals, dropping
# STZ/LIN — 0 signals, dropping
# APH/ACN — 44 signals, dropping
# STZ/ECL — 233 signals, keeping
# STZ/IT — 224 signals, keeping
# BLK/ACN — 206 signals, keeping
# NKE/IT — 195 signals, dropping
# BLK/IT — 389 signals, keeping
# NKE/TEL — 168 signals, dropping
# APH/LIN — 99 signals, dropping
# APH/EL — 231 signals, keeping
# APH/STZ — 164 signals, dropping
# APO/MSI — 270 signals, keeping
# APO/TEL — 87 signals, dropping
# BLK/ARES — 313 signals, keeping
# BLK/PAYX — 65 signals, dropping
# BLK/CSX — 277 signals, keeping
# APO/PAYX — 0 signals, dropping
# APO/CSX — 81 signals, dropping
# APO/ACN — 204 signals, keeping
# GRMN/IT — 282 signals, keeping
# APO/HPQ — 184 signals, dropping
# APO/ECL — 70 signals, dropping
# GRMN/ACN — 203 signals, keeping
# GRMN/CSX — 146 signals, dropping
# NKE/CSX — 151 signals, dropping
# NKE/KKR — 417 signals, keeping
# NKE/CRH — 216 signals, keeping
# STZ/ACN — 0 signals, dropping
# EL/LIN — 8 signals, dropping
# EL/HPQ — 177 signals, dropping
# EL/APO — 253 signals, keeping
# APH/ARES — 200 signals, keeping
# APH/CRH — 303 signals, keeping
# APH/ECL — 114 signals, dropping
# APH/APO — 235 signals, keeping
# KKR/CBRE — 198 signals, dropping
# LIN/PAYX — 179 signals, dropping
# LIN/ECL — 115 signals, dropping
# LIN/ACN — 189 signals, dropping
# WY/IT — 147 signals, dropping
# WY/MSI — 146 signals, dropping
# LIN/MSI — 186 signals, dropping
# GRMN/APO — 0 signals, dropping
# WY/CBRE — 230 signals, keeping
# WY/ACN — 178 signals, dropping
# WY/KKR — 89 signals, dropping
# WY/ARES — 229 signals, keeping
# KKR/CSX — 125 signals, dropping
# CSX/ACN — 162 signals, dropping
# CSX/MSI — 214 signals, keeping
# CSX/IT — 222 signals, keeping
# ACN/MSI — 248 signals, keeping
# KKR/IT — 0 signals, dropping
# KKR/TEL — 249 signals, keeping
# CBRE/IT — 222 signals, keeping
# CBRE/TEL — 181 signals, dropping
# ARES/CSX — 128 signals, dropping
# CRH/IT — 139 signals, dropping
# ARES/ACN — 157 signals, dropping
# GRMN/ECL — 72 signals, dropping
# GRMN/ARES — 373 signals, keeping
# CDW/IT — 0 signals, dropping
# CTSH/AMCR — 243 signals, keeping
# CTSH/STZ — 242 signals, keeping
# ARES/MSI — 110 signals, dropping
# CTSH/GRMN — 1 signals, dropping
# CTSH/LIN — 157 signals, dropping
# EL/IT — 60 signals, dropping
# EL/TEL — 244 signals, keeping
# EL/ACN — 166 signals, dropping
# EL/MSI — 111 signals, dropping
# EL/CSX — 263 signals, keeping
# EL/CRH — 223 signals, keeping
# EL/PAYX — 200 signals, keeping
# EL/ECL — 141 signals, dropping
# WY/APO — 142 signals, dropping
# WY/LIN — 174 signals, dropping
# WY/CRH — 114 signals, dropping
# WY/HPQ — 230 signals, keeping
# CTSH/BLK — 192 signals, dropping
# APH/MSI — 12 signals, dropping
# HAS/APO — 351 signals, keeping
# IT/TEL — 125 signals, dropping
# HAS/CSX — 231 signals, keeping
# BLK/ECL — 179 signals, dropping
# WY/CSX — 215 signals, keeping
# GRMN/MSI — 162 signals, dropping
# CDW/APH — 0 signals, dropping
# EL/ARES — 289 signals, keeping
# CDW/CSX — 252 signals, keeping
# CTSH/WY — 193 signals, dropping
# CDW/CTSH — 304 signals, keeping
# EL/GRMN — 193 signals, dropping
# APH/CSX — 244 signals, keeping
# CDW/APO — 270 signals, keeping
# CTSH/ARES — 357 signals, keeping
# STZ/BLK — 455 signals, keeping
# STZ/CSX — 214 signals, keeping
# LIN/BLK — 327 signals, keeping
# APO/CRH — 214 signals, keeping
# EL/WY — 183 signals, dropping
# GRMN/PAYX — 50 signals, dropping
# CRH/CBRE — 178 signals, dropping
# AMCR/NKE — 225 signals, keeping
# HAS/WY — 134 signals, dropping
# LIN/GRMN — 0 signals, dropping
# APO/IT — 0 signals, dropping
# STZ/GRMN — 0 signals, dropping
# CDW/CRH — 240 signals, keeping
# CDW/AMCR — 248 signals, keeping
# CDW/WY — 224 signals, keeping
# CRH/TEL — 0 signals, dropping
# CTSH/CRH — 240 signals, keeping
# LIN/CSX — 218 signals, keeping
# CTSH/APO — 0 signals, dropping
# CTSH/KKR — 381 signals, keeping
# CDW/EL — 405 signals, keeping
# EL/CBRE — 216 signals, keeping
# APO/ARES — 261 signals, keeping
# ECL/ARES — 50 signals, dropping
# CDW/CBRE — 228 signals, keeping
# CDW/KKR — 258 signals, keeping
# ECL/KKR — 307 signals, keeping
# PAYX/ARES — 0 signals, dropping
# APH/WY — 296 signals, keeping
# STZ/APO — 3 signals, dropping
# NKE/ECL — 175 signals, dropping
# STZ/ARES — 219 signals, keeping
# CDW/STZ — 194 signals, dropping
# CTSH/EL — 131 signals, dropping
# APH/CBRE — 223 signals, keeping
# AMCR/KKR — 278 signals, keeping
# APH/KKR — 246 signals, keeping
# STZ/CBRE — 333 signals, keeping
# NKE/CBRE — 0 signals, dropping
# STZ/CRH — 318 signals, keeping
# NKE/WY — 217 signals, keeping
# PAYX/IT — 71 signals, dropping
# STZ/KKR — 272 signals, keeping
# AMCR/CBRE — 327 signals, keeping
# GRMN/BLK — 196 signals, dropping
# LIN/KKR — 0 signals, dropping
# AMCR/HAS — 233 signals, keeping
# BLK/CRH — 76 signals, dropping
# STZ/EL — 176 signals, dropping
# AMCR/CRH — 0 signals, dropping
# LIN/ARES — 110 signals, dropping
# NKE/STZ — 203 signals, keeping
# GRMN/KKR — 233 signals, keeping
# NKE/APH — 74 signals, dropping
# CSX/TEL — 166 signals, dropping
# APH/BLK — 264 signals, keeping
# PAYX/CRH — 214 signals, keeping
# PAYX/KKR — 445 signals, keeping
# PAYX/TEL — 0 signals, dropping
# MSI/TEL — 325 signals, keeping
# CTSH/APH — 73 signals, dropping
# APH/TEL — 122 signals, dropping
# EL/BLK — 172 signals, dropping
# CTSH/PAYX — 202 signals, keeping
# CDW/MSI — 121 signals, dropping
# ECL/CRH — 0 signals, dropping
# STZ/TEL — 35 signals, dropping
# CTSH/ECL — 228 signals, keeping
# WY/TEL — 86 signals, dropping
# ACN/TEL — 185 signals, dropping
# ARES/KKR — 444 signals, keeping
# CDW/TEL — 297 signals, keeping
# NKE/PAYX — 0 signals, dropping
# LIN/TEL — 0 signals, dropping
# GRMN/TEL — 142 signals, dropping
# APH/PAYX — 21 signals, dropping
# HPQ/CBRE — 151 signals, dropping
# APO/CBRE — 219 signals, keeping
# HPQ/MSI — 136 signals, dropping
# HPQ/PAYX — 0 signals, dropping
# NKE/BLK — 83 signals, dropping
# ARES/IT — 444 signals, keeping
# AMCR/WY — 135 signals, dropping
# ARES/CBRE — 201 signals, keeping
# NKE/GRMN — 463 signals, keeping
# NKE/ARES — 383 signals, keeping
# STZ/WY — 265 signals, keeping
# GRMN/HPQ — 53 signals, dropping
# APH/HPQ — 263 signals, keeping
# BLK/MSI — 132 signals, dropping
# CDW/GRMN — 90 signals, dropping
# STZ/HPQ — 84 signals, dropping
# PAYX/CSX — 325 signals, keeping
# PAYX/ACN — 0 signals, dropping
# LIN/APO — 322 signals, keeping
# HAS/ARES — 268 signals, keeping
# CTSH/TEL — 0 signals, dropping
# KKR/ACN — 254 signals, keeping
# EL/KKR — 0 signals, dropping
# CTSH/CBRE — 323 signals, keeping
# AMCR/HPQ — 39 signals, dropping
# KKR/MSI — 128 signals, dropping
# AMCR/TEL — 95 signals, dropping
# HAS/PAYX — 319 signals, keeping
# NKE/ACN — 244 signals, keeping
# HPQ/CSX — 246 signals, keeping
# CTSH/HAS — 290 signals, keeping
# ARES/TEL — 390 signals, keeping
# BLK/TEL — 373 signals, keeping
# CDW/ECL — 154 signals, dropping
# CTSH/HPQ — 393 signals, keeping
# ECL/IT — 141 signals, dropping
# ECL/CSX — 178 signals, dropping
# NKE/MSI — 95 signals, dropping
# HAS/MSI — 211 signals, keeping
# APO/KKR — 250 signals, keeping
# CDW/NKE — 345 signals, keeping
# ECL/TEL — 0 signals, dropping
# ACN/IT — 137 signals, dropping
# NKE/LIN — 223 signals, keeping
# BLK/KKR — 289 signals, keeping
# WY/BLK — 423 signals, keeping
# CDW/PAYX — 230 signals, keeping
# ECL/CBRE — 255 signals, keeping
# CDW/HPQ — 248 signals, keeping
# LIN/HPQ — 11 signals, dropping
# BLK/HPQ — 228 signals, keeping
# PAYX/MSI — 202 signals, keeping
# LIN/CRH — 364 signals, keeping
# PAYX/CBRE — 307 signals, keeping
# CDW/BLK — 208 signals, keeping
# MSI/IT — 311 signals, keeping
# HPQ/ARES — 314 signals, keeping
# LIN/IT — 519 signals, keeping
# AMCR/CSX — 25 signals, dropping
# APH/GRMN — 0 signals, dropping
# HPQ/ECL — 63 signals, dropping
# WY/ECL — 197 signals, dropping
# HAS/APH — 177 signals, dropping
# HAS/LIN — 155 signals, dropping
# CDW/ARES — 0 signals, dropping
# ECL/PAYX — 267 signals, keeping
# HAS/BLK — 396 signals, keeping
# CTSH/NKE — 0 signals, dropping
# HAS/GRMN — 246 signals, keeping
# AMCR/LIN — 185 signals, dropping
# GRMN/CRH — 69 signals, dropping
# LIN/CBRE — 358 signals, keeping
# CBRE/CSX — 253 signals, keeping
# GRMN/CBRE — 0 signals, dropping
# AMCR/GRMN — 204 signals, keeping
# STZ/MSI — 205 signals, keeping
# BLK/CBRE — 183 signals, dropping
# STZ/PAYX — 57 signals, dropping
# WY/GRMN — 193 signals, dropping
# AMCR/ECL — 237 signals, keeping
# AMCR/PAYX — 249 signals, keeping
# APO/BLK — 359 signals, keeping
# WY/PAYX — 176 signals, dropping
# HAS/ACN — 216 signals, keeping
# CRH/ACN — 231 signals, keeping
# HAS/NKE — 1 signals, dropping
# CRH/CSX — 0 signals, dropping
# CRH/MSI — 359 signals, keeping
# CBRE/ACN — 157 signals, dropping
# CDW/ACN — 113 signals, dropping
# CBRE/MSI — 207 signals, keeping
#
# 140 pairs kept from 300

# %%
for _, row in active_pairs.iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0, parse_dates=True)
    
    full_spread = df['spread']
    train_spread = full_spread.loc[train_start:train_end]
    lsh, signatures = build_lsh_index(train_spread)  # only learn from train

    minhash_signals = compute_minhash_signals(full_spread, df['signal'], lsh, signatures)
    
    df['minhash_signal'] = minhash_signals
    df['final_signal'] = df.apply(
        lambda r: combine_signals(r['signal'], r['minhash_signal']), axis=1
    )
    
    df.to_csv(filename)
    print(f"done: {a}/{b}")
# Out:
# done: CDW/HAS
# done: CTSH/CSX
# done: HAS/EL
# done: AMCR/ACN
# done: AMCR/MSI
# done: AMCR/ARES
# done: AMCR/EL
# done: AMCR/IT
# done: HAS/CRH
# done: NKE/EL
# done: ECL/ACN
# done: STZ/ECL
# done: STZ/IT
# done: BLK/ACN
# done: BLK/IT
# done: APH/EL
# done: APO/MSI
# done: BLK/ARES
# done: BLK/CSX
# done: APO/ACN
# done: GRMN/IT
# done: GRMN/ACN
# done: NKE/KKR
# done: NKE/CRH
# done: EL/APO
# done: APH/ARES
# done: APH/CRH
# done: APH/APO
# done: WY/CBRE
# done: WY/ARES
# done: CSX/MSI
# done: CSX/IT
# done: ACN/MSI
# done: KKR/TEL
# done: CBRE/IT
# done: GRMN/ARES
# done: CTSH/AMCR
# done: CTSH/STZ
# done: EL/TEL
# done: EL/CSX
# done: EL/CRH
# done: EL/PAYX
# done: WY/HPQ
# done: HAS/APO
# done: HAS/CSX
# done: WY/CSX
# done: EL/ARES
# done: CDW/CSX
# done: CDW/CTSH
# done: APH/CSX
# done: CDW/APO
# done: CTSH/ARES
# done: STZ/BLK
# done: STZ/CSX
# done: LIN/BLK
# done: APO/CRH
# done: AMCR/NKE
# done: CDW/CRH
# done: CDW/AMCR
# done: CDW/WY
# done: CTSH/CRH
# done: LIN/CSX
# done: CTSH/KKR
# done: CDW/EL
# done: EL/CBRE
# done: APO/ARES
# done: CDW/CBRE
# done: CDW/KKR
# done: ECL/KKR
# done: APH/WY
# done: STZ/ARES
# done: APH/CBRE
# done: AMCR/KKR
# done: APH/KKR
# done: STZ/CBRE
# done: STZ/CRH
# done: NKE/WY
# done: STZ/KKR
# done: AMCR/CBRE
# done: AMCR/HAS
# done: NKE/STZ
# done: GRMN/KKR
# done: APH/BLK
# done: PAYX/CRH
# done: PAYX/KKR
# done: MSI/TEL
# done: CTSH/PAYX
# done: CTSH/ECL
# done: ARES/KKR
# done: CDW/TEL
# done: APO/CBRE
# done: ARES/IT
# done: ARES/CBRE
# done: NKE/GRMN
# done: NKE/ARES
# done: STZ/WY
# done: APH/HPQ
# done: PAYX/CSX
# done: LIN/APO
# done: HAS/ARES
# done: KKR/ACN
# done: CTSH/CBRE
# done: HAS/PAYX
# done: NKE/ACN
# done: HPQ/CSX
# done: CTSH/HAS
# done: ARES/TEL
# done: BLK/TEL
# done: CTSH/HPQ
# done: HAS/MSI
# done: APO/KKR
# done: CDW/NKE
# done: NKE/LIN
# done: BLK/KKR
# done: WY/BLK
# done: CDW/PAYX
# done: ECL/CBRE
# done: CDW/HPQ
# done: BLK/HPQ
# done: PAYX/MSI
# done: LIN/CRH
# done: PAYX/CBRE
# done: CDW/BLK
# done: MSI/IT
# done: HPQ/ARES
# done: LIN/IT
# done: ECL/PAYX
# done: HAS/BLK
# done: HAS/GRMN
# done: LIN/CBRE
# done: CBRE/CSX
# done: AMCR/GRMN
# done: STZ/MSI
# done: AMCR/ECL
# done: AMCR/PAYX
# done: APO/BLK
# done: HAS/ACN
# done: CRH/ACN
# done: CRH/MSI
# done: CBRE/MSI

# %%
# plot first 10 final signal distributions
for _, row in active_pairs.head(10).iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0, parse_dates=True)
    
    plt.figure(figsize=(6, 4))
    df['final_signal'].value_counts().sort_index().plot(kind='bar')
    plt.title(f"{a}/{b} Final Signal Distribution")
    plt.xlabel('Final Signal')
    plt.ylabel('Count')
    plt.xticks(rotation=0)
    plt.show()

# %% [markdown]
# From first ten pairs, we see that we are not trading an overwhelming majority of the time and may be slightly biased towards long trades.
