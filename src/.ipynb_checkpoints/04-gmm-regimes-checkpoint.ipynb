# %% [markdown]
# # Gaussian Mixture Modeling Regimes

# %%
from sklearn.mixture import GaussianMixture
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filtered_residuals = pd.read_csv("../data/manipulated/pr_filtered_residuals.csv", index_col=0, parse_dates=True)
train_residuals = pd.read_csv("../data/manipulated/residuals_train.csv", index_col=0, parse_dates=True)

train_start = train_residuals.index.min()
train_end = train_residuals.index.max()

filtered_train_residuals = filtered_residuals.loc[train_start:train_end]

cointegration_pairs = pd.read_csv('../data/manipulated/cointegrated_pairs.csv')

# %%
cointegration_pairs.head()
# Out:
#   asset_a asset_b  pvalue      beta
# 0     CDW     HAS     0.0  1.245548
# 1    CTSH     ACN     0.0  0.833156
# 2    CTSH     CSX     0.0  0.874627
# 3    CTSH      IT     0.0  0.969965
# 4    CTSH     MSI     0.0  0.976822

# %%
def plot_bic(
        spread: pd.Series,
        k_range: range = [2, 3, 4, 5]
        ) -> None:
        """
        Plot the Bayesian Information Criterion (BIC) for different numbers of components in a Gaussian Mixture Model.
        """

        X = spread.values.reshape(-1, 1)
        bic_scores = []

        for k in k_range:
                gmm = GaussianMixture(
                n_components=k,
                covariance_type="full",
                random_state=42,
                n_init=5,          # multiple initialisations for stability
                )
                gmm.fit(X)
                bic_scores.append((k, gmm.bic(X)))

        plt.plot([k for k, _ in bic_scores], [bic for _, bic in bic_scores], marker='o')
        plt.title('BIC Scores for GMM')
        plt.xlabel('Number of Components (k)')
        plt.ylabel('BIC Score')
        plt.xticks([k for k, _ in bic_scores])
        plt.grid()
        plt.show()

# %%
def select_best_k(
    spread: pd.Series,
    k_range: range = [2, 3, 4, 5],
    ) -> int:
    """
    Select the optimal number of GMM components using BIC.

    Lower BIC => better model.

    Args:
        spread:  1D spread time series (training portion only).
        k_range: Range of k values to evaluate.

    Returns:
        best_k:  Optimal number of components.
        bic_scores: List of (k, bic) tuples for all tested values.
    """
    X = spread.values.reshape(-1, 1)
    bic_scores = []

    for k in k_range:
        gmm = GaussianMixture(
            n_components=k,
            covariance_type="full",
            random_state=42,
            n_init=5,          # multiple initialisations for stability
        )
        gmm.fit(X)
        bic_scores.append((k, gmm.bic(X)))

    best_k = min(bic_scores, key=lambda x: x[1])[0]
    return best_k

# %%
def fit_gmm(
    spread: pd.Series,
    n_components: int,
) -> GaussianMixture:
    """
    Fit a GaussianMixture model to a spread series.

    Args:
        spread:       1D spread time series (training portion only).
        n_components: Number of Gaussian components (regimes).

    Returns:
        Fitted GaussianMixture object.
    """
    X = spread.values.reshape(-1, 1)
    gmm = GaussianMixture(
        n_components=n_components,
        covariance_type="full",
        random_state=42,
        n_init=5,
    )
    gmm.fit(X)
    return gmm

# %%
for i, row in cointegration_pairs.iterrows():
    a = row['asset_a']
    b = row['asset_b']
    beta = row['beta']
    
    train_spread = filtered_train_residuals[a] - beta * filtered_train_residuals[b]
    full_spread = filtered_residuals[a] - beta * filtered_residuals[b]
    
    best_k = select_best_k(train_spread)
    gmm = fit_gmm(train_spread, best_k)
    plot_bic(full_spread)

    regimes = gmm.predict(full_spread.values.reshape(-1, 1))
    plt.figure(figsize=(12, 6))
    plt.plot(full_spread.index, full_spread.values, label='Spread')
    plt.scatter(full_spread.index, full_spread.values, c=regimes, label=f'Regimes (k={best_k})', cmap='viridis', marker='o')
    plt.title(f'Spread and Regimes for {a} & {b} (beta={beta:.2f})')
    plt.xlabel('Time')
    plt.ylabel('Spread')
    plt.legend()
    plt.show()

    if i >= 4:  # Limit to first 5 pairs for demonstration
        break

# %%
for _, row in cointegration_pairs.iterrows():
    a, b, beta = row['asset_a'], row['asset_b'], row['beta']
        
    train_spread = filtered_train_residuals[a] - beta * filtered_train_residuals[b]
    full_spread = filtered_residuals[a] - beta * filtered_residuals[b]
    
    best_k = select_best_k(train_spread)
    gmm = fit_gmm(train_spread, best_k)
    labels = gmm.predict(full_spread.values.reshape(-1, 1))
    
    # sort regimes by mean for consistency across pairs
    sorted_idx    = np.argsort(gmm.means_.flatten())
    remap         = {old: new for new, old in enumerate(sorted_idx)}
    sorted_labels = np.array([remap[l] for l in labels])
    
    # global z-score
    z_scores = (full_spread - full_spread.mean()) / full_spread.std()
    
    # calm regime = lowest std after sorting
    sorted_stds = np.sqrt(gmm.covariances_.flatten())[sorted_idx]
    calm_regime = int(np.argmin(sorted_stds))
    
    # signals: only enter in calm regime
    signal = pd.Series(0, index=full_spread.index)
    signal[(z_scores < -1.5) & (sorted_labels == calm_regime)] =  1
    signal[(z_scores >  1.5) & (sorted_labels == calm_regime)] = -1
    signal[z_scores.abs() < 0.3] = 0
    
    df = pd.DataFrame({
        'spread':  full_spread.values,
        'regime':  sorted_labels,
        'z_score': z_scores.values,
        'signal':  signal.values,
    }, index=full_spread.index)
    
    df.to_csv(f'../data/manipulated/spreads/{a}_{b}.csv')

print(f'saved {len(cointegration_pairs)} spread files')
# Out:
# saved 300 spread files

# %%
for i, row in cointegration_pairs.iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0)

    plt.figure(figsize=(8, 4))
    df['signal'].value_counts().sort_index().plot(kind='bar')
    plt.title(f'Signal Distribution for {a} & {b}')
    plt.xlabel('Signal')
    plt.ylabel('Count')
    plt.xticks(ticks=[-1, 0, 1])
    plt.show()

    if i >= 9:  # Limit to first 10 pairs for demonstration
        break

# %% [markdown]
# Not enough spreads are being classified as tradeable.

# %%
for i, row in cointegration_pairs.iterrows():
    filename = f"../data/manipulated/spreads/{row['asset_a']}_{row['asset_b']}.csv"
    df = pd.read_csv(filename, index_col=0)
    print(f'Z-Score Statistics for {row["asset_a"]} & {row["asset_b"]}:')
    print(df['z_score'].describe())
    print(df['z_score'].abs().quantile([0.8, 0.9, 0.95, 0.99]))
    print()

    if i >= 9:  # Limit to first 10 pairs for demonstration
        break
# Out:
# Z-Score Statistics for CDW & HAS:
# count    2.387000e+03
# mean    -2.083703e-17
# std      1.000000e+00
# min     -5.833291e+00
# 25%     -6.206231e-01
# 50%     -2.881564e-02
# 75%      5.388760e-01
# max      5.892507e+00
# Name: z_score, dtype: float64
# 0.80    1.132059
# 0.90    1.556859
# 0.95    2.006924
# 0.99    3.142803
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & ACN:
# count    2.387000e+03
# mean    -8.930156e-18
# std      1.000000e+00
# min     -1.278044e+01
# 25%     -4.842711e-01
# 50%      4.750265e-03
# 75%      5.166080e-01
# max      5.010314e+00
# Name: z_score, dtype: float64
# 0.80    1.082331
# 0.90    1.465370
# 0.95    1.929085
# 0.99    3.456708
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & CSX:
# count    2.387000e+03
# mean     1.339523e-17
# std      1.000000e+00
# min     -5.859627e+00
# 25%     -6.126224e-01
# 50%     -4.967386e-02
# 75%      5.649253e-01
# max      4.340631e+00
# Name: z_score, dtype: float64
# 0.80    1.139729
# 0.90    1.578276
# 0.95    1.995990
# 0.99    3.272013
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & IT:
# count    2.387000e+03
# mean     5.209258e-18
# std      1.000000e+00
# min     -1.379363e+01
# 25%     -5.229945e-01
# 50%     -1.670786e-02
# 75%      5.138018e-01
# max      1.502010e+01
# Name: z_score, dtype: float64
# 0.80    1.020878
# 0.90    1.364949
# 0.95    1.749390
# 0.99    2.642660
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & MSI:
# count    2.387000e+03
# mean     1.004643e-17
# std      1.000000e+00
# min     -6.808346e+00
# 25%     -4.941478e-01
# 50%      2.889265e-02
# 75%      5.339039e-01
# max      8.383191e+00
# Name: z_score, dtype: float64
# 0.80    1.137934
# 0.90    1.564265
# 0.95    2.000208
# 0.99    3.195621
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CDW & LIN:
# count    2.387000e+03
# mean    -8.930156e-18
# std      1.000000e+00
# min     -8.825852e+00
# 25%     -5.424397e-01
# 50%     -2.587314e-02
# 75%      5.060711e-01
# max      5.996483e+00
# Name: z_score, dtype: float64
# 0.80    1.119535
# 0.90    1.520942
# 0.95    2.015046
# 0.99    3.049085
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HAS & EL:
# count    2.387000e+03
# mean    -1.488359e-17
# std      1.000000e+00
# min     -8.147470e+00
# 25%     -4.854541e-01
# 50%      4.361301e-02
# 75%      5.439102e-01
# max      7.770622e+00
# Name: z_score, dtype: float64
# 0.80    1.079192
# 0.90    1.500772
# 0.95    1.992219
# 0.99    3.469482
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HPQ & CRH:
# count    2.387000e+03
# mean    -4.465078e-18
# std      1.000000e+00
# min     -7.037851e+00
# 25%     -5.863755e-01
# 50%     -1.930161e-02
# 75%      5.463518e-01
# max      4.536132e+00
# Name: z_score, dtype: float64
# 0.80    1.155674
# 0.90    1.559303
# 0.95    2.014055
# 0.99    2.995648
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & ACN:
# count    2.387000e+03
# mean    -1.488359e-17
# std      1.000000e+00
# min     -6.447225e+00
# 25%     -4.569146e-01
# 50%      4.853179e-02
# 75%      5.049463e-01
# max      8.466183e+00
# Name: z_score, dtype: float64
# 0.80    1.066630
# 0.90    1.494784
# 0.95    1.974621
# 0.99    3.364350
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & MSI:
# count    2.387000e+03
# mean    -5.953437e-18
# std      1.000000e+00
# min     -5.962695e+00
# 25%     -4.658495e-01
# 50%      2.846254e-02
# 75%      5.566181e-01
# max      6.519722e+00
# Name: z_score, dtype: float64
# 0.80    1.077855
# 0.90    1.504200
# 0.95    2.046623
# 0.99    3.562741
# Name: z_score, dtype: float64

# %% [markdown]
# The z-score statistics for most pairs appear to be approximately standard normal. The good news is that this means the GMM regimes are very well separated, meaning each spread within a regime looks normal to that regime. The bad news is that this means z-scoring within regimes is not feasible for signaling, so I will instead implement global z-scoring across all regimes and then use the regimes as volatility indicators, e.g. an extreme z-score + a stable regime means we expect the spread to stabilize.
#
# For now, classify the lowest stdev regime as the calm one and trade in it only.

# %%
for _, row in cointegration_pairs.iterrows():
    a, b, beta = row['asset_a'], row['asset_b'], row['beta']
        
    train_spread = filtered_train_residuals[a] - beta * filtered_train_residuals[b]
    full_spread = filtered_residuals[a] - beta * filtered_residuals[b]
    
    best_k = select_best_k(train_spread)
    gmm = fit_gmm(train_spread, best_k)
    labels = gmm.predict(full_spread.values.reshape(-1, 1))
    
    # sort regimes by mean for consistency across pairs
    sorted_idx    = np.argsort(gmm.means_.flatten())
    remap         = {old: new for new, old in enumerate(sorted_idx)}
    sorted_labels = np.array([remap[l] for l in labels])
    
    # global z-score
    z_scores = (full_spread - full_spread.mean()) / full_spread.std()
    
    # calm regime = lowest std after sorting
    sorted_stds = np.sqrt(gmm.covariances_.flatten())[sorted_idx]
    calm_regime = int(np.argmin(sorted_stds))
    
    # signals: only enter in calm regime
    signal = pd.Series(0, index=full_spread.index)
    signal[(z_scores < -1.5) & (sorted_labels == calm_regime)] =  1
    signal[(z_scores >  1.5) & (sorted_labels == calm_regime)] = -1
    signal[z_scores.abs() < 0.3] = 0
    
    df = pd.DataFrame({
        'spread':  full_spread.values,
        'regime':  sorted_labels,
        'z_score': z_scores.values,
        'signal':  signal.values,
    }, index=full_spread.index)
    
    df.to_csv(f'../data/manipulated/spreads/{a}_{b}.csv')

print(f'saved {len(cointegration_pairs)} spread files')
# Out:
# saved 300 spread files

# %%
# print signal distribution for each pair
for i, row in cointegration_pairs.iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0)

    print(f'Signal Distribution for {a} & {b}:')
    print(df['signal'].value_counts().sort_index())
    print()

    if i >= 19: # Limit to first 20 pairs for demonstration
        break
# Out:
# Signal Distribution for CDW & HAS:
# signal
# 0    2382
# 1       5
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & ACN:
# signal
# 0    2384
# 1       3
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & CSX:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & IT:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & MSI:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for CDW & LIN:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for HAS & EL:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for HPQ & CRH:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & ACN:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & MSI:
# signal
# -1       3
#  0    2384
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & ARES:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & BLK:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & APO:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & EL:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & STZ:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & APH:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & IT:
# signal
# -1       7
#  0    2380
# Name: count, dtype: int64
#
# Signal Distribution for HAS & STZ:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for HAS & CRH:
# signal
# 0    2359
# 1      28
# Name: count, dtype: int64
#
# Signal Distribution for HAS & KKR:
# signal
# 0    2387
# Name: count, dtype: int64

# %%
for i, row in cointegration_pairs.iterrows():
    filename = f"../data/manipulated/spreads/{row['asset_a']}_{row['asset_b']}.csv"
    df = pd.read_csv(filename, index_col=0)
    print(f'Z-Score Statistics for {row["asset_a"]} & {row["asset_b"]}:')
    print(df['z_score'].describe())
    print(df['z_score'].abs().quantile([0.8, 0.9, 0.95, 0.99]))
    print()

    if i >= 19: # Limit to first 20 pairs for demonstration
        break
# Out:
# Z-Score Statistics for CDW & HAS:
# count    2.387000e+03
# mean    -2.083703e-17
# std      1.000000e+00
# min     -5.833291e+00
# 25%     -6.206231e-01
# 50%     -2.881564e-02
# 75%      5.388760e-01
# max      5.892507e+00
# Name: z_score, dtype: float64
# 0.80    1.132059
# 0.90    1.556859
# 0.95    2.006924
# 0.99    3.142803
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & ACN:
# count    2.387000e+03
# mean    -8.930156e-18
# std      1.000000e+00
# min     -1.278044e+01
# 25%     -4.842711e-01
# 50%      4.750265e-03
# 75%      5.166080e-01
# max      5.010314e+00
# Name: z_score, dtype: float64
# 0.80    1.082331
# 0.90    1.465370
# 0.95    1.929085
# 0.99    3.456708
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & CSX:
# count    2.387000e+03
# mean     1.339523e-17
# std      1.000000e+00
# min     -5.859627e+00
# 25%     -6.126224e-01
# 50%     -4.967386e-02
# 75%      5.649253e-01
# max      4.340631e+00
# Name: z_score, dtype: float64
# 0.80    1.139729
# 0.90    1.578276
# 0.95    1.995990
# 0.99    3.272013
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & IT:
# count    2.387000e+03
# mean     5.209258e-18
# std      1.000000e+00
# min     -1.379363e+01
# 25%     -5.229945e-01
# 50%     -1.670786e-02
# 75%      5.138018e-01
# max      1.502010e+01
# Name: z_score, dtype: float64
# 0.80    1.020878
# 0.90    1.364949
# 0.95    1.749390
# 0.99    2.642660
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CTSH & MSI:
# count    2.387000e+03
# mean     1.004643e-17
# std      1.000000e+00
# min     -6.808346e+00
# 25%     -4.941478e-01
# 50%      2.889265e-02
# 75%      5.339039e-01
# max      8.383191e+00
# Name: z_score, dtype: float64
# 0.80    1.137934
# 0.90    1.564265
# 0.95    2.000208
# 0.99    3.195621
# Name: z_score, dtype: float64
#
# Z-Score Statistics for CDW & LIN:
# count    2.387000e+03
# mean    -8.930156e-18
# std      1.000000e+00
# min     -8.825852e+00
# 25%     -5.424397e-01
# 50%     -2.587314e-02
# 75%      5.060711e-01
# max      5.996483e+00
# Name: z_score, dtype: float64
# 0.80    1.119535
# 0.90    1.520942
# 0.95    2.015046
# 0.99    3.049085
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HAS & EL:
# count    2.387000e+03
# mean    -1.488359e-17
# std      1.000000e+00
# min     -8.147470e+00
# 25%     -4.854541e-01
# 50%      4.361301e-02
# 75%      5.439102e-01
# max      7.770622e+00
# Name: z_score, dtype: float64
# 0.80    1.079192
# 0.90    1.500772
# 0.95    1.992219
# 0.99    3.469482
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HPQ & CRH:
# count    2.387000e+03
# mean    -4.465078e-18
# std      1.000000e+00
# min     -7.037851e+00
# 25%     -5.863755e-01
# 50%     -1.930161e-02
# 75%      5.463518e-01
# max      4.536132e+00
# Name: z_score, dtype: float64
# 0.80    1.155674
# 0.90    1.559303
# 0.95    2.014055
# 0.99    2.995648
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & ACN:
# count    2.387000e+03
# mean    -1.488359e-17
# std      1.000000e+00
# min     -6.447225e+00
# 25%     -4.569146e-01
# 50%      4.853179e-02
# 75%      5.049463e-01
# max      8.466183e+00
# Name: z_score, dtype: float64
# 0.80    1.066630
# 0.90    1.494784
# 0.95    1.974621
# 0.99    3.364350
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & MSI:
# count    2.387000e+03
# mean    -5.953437e-18
# std      1.000000e+00
# min     -5.962695e+00
# 25%     -4.658495e-01
# 50%      2.846254e-02
# 75%      5.566181e-01
# max      6.519722e+00
# Name: z_score, dtype: float64
# 0.80    1.077855
# 0.90    1.504200
# 0.95    2.046623
# 0.99    3.562741
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & ARES:
# count    2.387000e+03
# mean     2.083703e-17
# std      1.000000e+00
# min     -5.657451e+00
# 25%     -5.082156e-01
# 50%      3.254590e-02
# 75%      5.432896e-01
# max      1.082284e+01
# Name: z_score, dtype: float64
# 0.80    1.123328
# 0.90    1.508098
# 0.95    1.942577
# 0.99    3.074754
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & BLK:
# count    2.387000e+03
# mean    -2.976719e-18
# std      1.000000e+00
# min     -7.425216e+00
# 25%     -4.936427e-01
# 50%      1.719307e-02
# 75%      5.216457e-01
# max      1.307746e+01
# Name: z_score, dtype: float64
# 0.80    1.091088
# 0.90    1.449985
# 0.95    1.833335
# 0.99    3.237897
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & APO:
# count    2.387000e+03
# mean     4.465078e-18
# std      1.000000e+00
# min     -5.547199e+00
# 25%     -5.465393e-01
# 50%      1.432192e-02
# 75%      5.599736e-01
# max      9.533257e+00
# Name: z_score, dtype: float64
# 0.80    1.144672
# 0.90    1.534287
# 0.95    1.929656
# 0.99    2.970604
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & EL:
# count    2387.000000
# mean        0.000000
# std         1.000000
# min        -6.241269
# 25%        -0.498030
# 50%         0.046876
# 75%         0.540058
# max         8.891673
# Name: z_score, dtype: float64
# 0.80    1.136911
# 0.90    1.533726
# 0.95    1.983958
# 0.99    3.181966
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & STZ:
# count    2.387000e+03
# mean     7.441797e-18
# std      1.000000e+00
# min     -5.078788e+00
# 25%     -6.006447e-01
# 50%      9.199159e-03
# 75%      5.648507e-01
# max      6.398258e+00
# Name: z_score, dtype: float64
# 0.80    1.156358
# 0.90    1.559651
# 0.95    2.010808
# 0.99    2.991277
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & APH:
# count    2.387000e+03
# mean    -2.679047e-17
# std      1.000000e+00
# min     -4.700366e+00
# 25%     -5.309927e-01
# 50%      4.553668e-02
# 75%      5.490707e-01
# max      6.923199e+00
# Name: z_score, dtype: float64
# 0.80    1.150240
# 0.90    1.597704
# 0.95    2.058926
# 0.99    3.108465
# Name: z_score, dtype: float64
#
# Z-Score Statistics for AMCR & IT:
# count    2.387000e+03
# mean    -1.190687e-17
# std      1.000000e+00
# min     -6.463283e+00
# 25%     -5.198368e-01
# 50%      3.070892e-02
# 75%      5.845256e-01
# max      7.077956e+00
# Name: z_score, dtype: float64
# 0.80    1.163426
# 0.90    1.535299
# 0.95    2.007610
# 0.99    3.123377
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HAS & STZ:
# count    2.387000e+03
# mean    -1.488359e-18
# std      1.000000e+00
# min     -5.918271e+00
# 25%     -5.752197e-01
# 50%     -2.478436e-02
# 75%      5.436795e-01
# max      7.895734e+00
# Name: z_score, dtype: float64
# 0.80    1.155242
# 0.90    1.597902
# 0.95    1.995243
# 0.99    3.075962
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HAS & CRH:
# count    2.387000e+03
# mean     2.232539e-18
# std      1.000000e+00
# min     -7.071285e+00
# 25%     -5.792854e-01
# 50%     -1.382007e-02
# 75%      5.663901e-01
# max      6.770585e+00
# Name: z_score, dtype: float64
# 0.80    1.143667
# 0.90    1.510211
# 0.95    1.949326
# 0.99    3.035867
# Name: z_score, dtype: float64
#
# Z-Score Statistics for HAS & KKR:
# count    2.387000e+03
# mean     2.530211e-17
# std      1.000000e+00
# min     -5.384458e+00
# 25%     -5.510271e-01
# 50%      2.487563e-02
# 75%      5.365866e-01
# max      8.068405e+00
# Name: z_score, dtype: float64
# 0.80    1.160169
# 0.90    1.577550
# 0.95    1.943487
# 0.99    3.246137
# Name: z_score, dtype: float64

# %% [markdown]
# Lower z-score signal threshold, not triggering enough trades, all of them will be in relatively safe calm regime anyway (justify more later).

# %%
for _, row in cointegration_pairs.iterrows():
    a, b, beta = row['asset_a'], row['asset_b'], row['beta']
        
    train_spread = filtered_train_residuals[a] - beta * filtered_train_residuals[b]
    full_spread = filtered_residuals[a] - beta * filtered_residuals[b]
    
    best_k = select_best_k(train_spread)
    gmm = fit_gmm(train_spread, best_k)
    labels = gmm.predict(full_spread.values.reshape(-1, 1))
    
    # sort regimes by mean for consistency across pairs
    sorted_idx    = np.argsort(gmm.means_.flatten())
    remap         = {old: new for new, old in enumerate(sorted_idx)}
    sorted_labels = np.array([remap[l] for l in labels])
    
    # global z-score
    z_scores = (full_spread - full_spread.mean()) / full_spread.std()
    
    # calm regime = lowest std after sorting
    sorted_stds = np.sqrt(gmm.covariances_.flatten())[sorted_idx]
    calm_regime = int(np.argmin(sorted_stds))
    
    # signals: only enter in calm regime
    signal = pd.Series(0, index=full_spread.index)
    signal[(z_scores < -1) & (sorted_labels == calm_regime)] =  1
    signal[(z_scores >  1) & (sorted_labels == calm_regime)] = -1
    signal[z_scores.abs() < 0.2] = 0
    
    df = pd.DataFrame({
        'spread':  full_spread.values,
        'regime':  sorted_labels,
        'z_score': z_scores.values,
        'signal':  signal.values,
    }, index=full_spread.index)
    
    df.to_csv(f'../data/manipulated/spreads/{a}_{b}.csv')

print(f'saved {len(cointegration_pairs)} spread files')
# Out:
# saved 300 spread files

# %%
# print signal distribution for each pair
for i, row in cointegration_pairs.iterrows():
    a, b = row['asset_a'], row['asset_b']
    filename = f"../data/manipulated/spreads/{a}_{b}.csv"
    df = pd.read_csv(filename, index_col=0)

    print(f'Signal Distribution for {a} & {b}:')
    print(df['signal'].value_counts().sort_index())
    print()

    if i >= 19:
        break
# Out:
# Signal Distribution for CDW & HAS:
# signal
# -1      27
#  0    2158
#  1     202
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & ACN:
# signal
# -1      18
#  0    2220
#  1     149
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & CSX:
# signal
# -1      54
#  0    2162
#  1     171
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & IT:
# signal
# 0    2372
# 1      15
# Name: count, dtype: int64
#
# Signal Distribution for CTSH & MSI:
# signal
# -1     104
#  0    2274
#  1       9
# Name: count, dtype: int64
#
# Signal Distribution for CDW & LIN:
# signal
# -1      57
#  0    2232
#  1      98
# Name: count, dtype: int64
#
# Signal Distribution for HAS & EL:
# signal
# -1     166
#  0    2162
#  1      59
# Name: count, dtype: int64
#
# Signal Distribution for HPQ & CRH:
# signal
# -1      22
#  0    2252
#  1     113
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & ACN:
# signal
# -1     144
#  0    2181
#  1      62
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & MSI:
# signal
# -1     174
#  0    2146
#  1      67
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & ARES:
# signal
# -1     182
#  0    2087
#  1     118
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & BLK:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & APO:
# signal
# 0    2387
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & EL:
# signal
# -1     152
#  0    2163
#  1      72
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & STZ:
# signal
# -1     110
#  0    2277
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & APH:
# signal
# -1     122
#  0    2230
#  1      35
# Name: count, dtype: int64
#
# Signal Distribution for AMCR & IT:
# signal
# -1     188
#  0    2155
#  1      44
# Name: count, dtype: int64
#
# Signal Distribution for HAS & STZ:
# signal
# -1      15
#  0    2271
#  1     101
# Name: count, dtype: int64
#
# Signal Distribution for HAS & CRH:
# signal
# -1     186
#  0    1989
#  1     212
# Name: count, dtype: int64
#
# Signal Distribution for HAS & KKR:
# signal
# -1     123
#  0    2200
#  1      64
# Name: count, dtype: int64

# %% [markdown]
# Much more desirable split now.
